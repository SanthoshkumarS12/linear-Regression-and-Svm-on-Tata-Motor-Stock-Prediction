# %%
#import nessasary modules 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# # linear regression

# %%
#loading the dataset
dataset= pd.read_csv(r"C:\Users\santh\OneDrive\Desktop\studies\machine learning\mlproject\TATAMOTORS.csv")

# %%
dataset
# Out:
#             Date      Symbol Series  Prev Close   Open    High     Low  \
# 0     2000-01-03       TELCO     EQ      201.60  207.4  217.25  207.40
# 1     2000-01-04       TELCO     EQ      216.75  217.0  219.00  206.00
# 2     2000-01-05       TELCO     EQ      208.20  194.0  217.80  194.00
# 3     2000-01-06       TELCO     EQ      213.25  215.0  229.90  215.00
# 4     2000-01-07       TELCO     EQ      222.10  224.0  239.90  223.10
# ...          ...         ...    ...         ...    ...     ...     ...
# 5301  2021-04-26  TATAMOTORS     EQ      294.00  297.0  299.00  294.60
# 5302  2021-04-27  TATAMOTORS     EQ      295.40  295.7  302.50  295.10
# 5303  2021-04-28  TATAMOTORS     EQ      301.50  303.5  309.50  303.00
# 5304  2021-04-29  TATAMOTORS     EQ      305.90  308.9  310.00  301.25
# 5305  2021-04-30  TATAMOTORS     EQ      301.90  298.2  301.30  292.55
#
#         Last   Close    VWAP    Volume      Turnover    Trades  \
# ...

# %%
dataset[:5]
# Out:
#          Date Symbol Series  Prev Close   Open    High    Low   Last   Close  \
# 0  2000-01-03  TELCO     EQ      201.60  207.4  217.25  207.4  217.0  216.75
# 1  2000-01-04  TELCO     EQ      216.75  217.0  219.00  206.0  211.9  208.20
# 2  2000-01-05  TELCO     EQ      208.20  194.0  217.80  194.0  213.1  213.25
# 3  2000-01-06  TELCO     EQ      213.25  215.0  229.90  215.0  222.0  222.10
# 4  2000-01-07  TELCO     EQ      222.10  224.0  239.90  223.1  239.9  239.90
#
#      VWAP   Volume      Turnover  Trades  Deliverable Volume  %Deliverble
# 0  214.28   676126  1.448775e+13     NaN                 NaN          NaN
# 1  209.50   679215  1.422962e+13     NaN                 NaN          NaN
# 2  210.33  1120951  2.357684e+13     NaN                 NaN          NaN
# 3  225.29  1968998  4.435932e+13     NaN                 NaN          NaN
# 4  236.32  2199431  5.197636e+13     NaN                 NaN          NaN

# %%
x = dataset.iloc[:, 4:11]
print(x[4:11])
y = dataset.iloc[:, 11:12]
y[:5]
# Out:
#       Open   High     Low    Last   Close    VWAP   Volume
# 4   224.00  239.9  223.10  239.90  239.90  236.32  2199431
# 5   259.00  259.1  248.00  259.10  258.85  257.20  1720542
# 6   260.00  260.0  238.15  238.15  238.15  246.63  1207916
# 7   240.00  246.0  229.00  242.45  240.25  237.13   938579
# 8   243.00  245.0  231.60  233.00  235.45  237.31   565754
# 9   234.95  243.0  233.00  239.80  239.05  239.04  1024725
# 10  242.95  258.1  242.95  251.00  250.65  252.65  1482994
#        Turnover
# 0  1.448775e+13
# 1  1.422962e+13
# 2  2.357684e+13
# 3  4.435932e+13
# 4  5.197636e+13

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
regressor=LinearRegression()

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred= regressor.predict(x_test)

# %%
print('Training score ',regressor.score(x_train,y_train)*100)
print('Testing score',regressor.score(x_test,y_test)*100)
# Out:
# Training score  79.69727830239033
# Testing score 81.4801947552933

# %%
np.reshape(y_pred,(-1))
# Out:
# array([1.84740694e+14, 7.52215706e+12, 5.75300290e+14, ...,
#        1.77755030e+14, 2.04284453e+14, 4.45870301e+13])

# %%
np.reshape(y_test,(-1))
# Out:
#           Turnover
# 3655  2.243192e+14
# 29    1.134930e+13
# 5135  3.809460e+14
# 3671  2.886175e+14
# 4681  2.019665e+14
# ...            ...
# 1804  7.607553e+13
# 1830  1.086789e+14
# 1191  2.410531e+14
# 3858  3.070386e+14
# 729   4.403940e+13
#
# [1062 rows x 1 columns]

# %%
plt.plot(y_test,y_pred)

# %% [markdown]
# # PCA

# %%
DS =pd.read_csv(r"C:\Users\santh\OneDrive\Desktop\studies\machine learning\mlproject\TATAMOTORS.csv")

# %%
DS
# Out:
#             Date      Symbol Series  Prev Close   Open    High     Low  \
# 0     2000-01-03       TELCO     EQ      201.60  207.4  217.25  207.40
# 1     2000-01-04       TELCO     EQ      216.75  217.0  219.00  206.00
# 2     2000-01-05       TELCO     EQ      208.20  194.0  217.80  194.00
# 3     2000-01-06       TELCO     EQ      213.25  215.0  229.90  215.00
# 4     2000-01-07       TELCO     EQ      222.10  224.0  239.90  223.10
# ...          ...         ...    ...         ...    ...     ...     ...
# 5301  2021-04-26  TATAMOTORS     EQ      294.00  297.0  299.00  294.60
# 5302  2021-04-27  TATAMOTORS     EQ      295.40  295.7  302.50  295.10
# 5303  2021-04-28  TATAMOTORS     EQ      301.50  303.5  309.50  303.00
# 5304  2021-04-29  TATAMOTORS     EQ      305.90  308.9  310.00  301.25
# 5305  2021-04-30  TATAMOTORS     EQ      301.90  298.2  301.30  292.55
#
#         Last   Close    VWAP    Volume      Turnover    Trades  \
# ...

# %%
X = DS.iloc[: , 3:11].values  
Y = DS.iloc[: , 11:12].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
SC = StandardScaler()   
X_train = SC.fit_transform(X_train) 
print(X_train)
X_test = SC.transform(X_test)  
print(X_test)
# Out:
# [[-0.71569425 -0.72932352 -0.73805685 ... -0.74194789 -0.73550962
#    0.52144447]
#  [-1.14624627 -1.15008794 -1.15140058 ... -1.15184511 -1.15146753
#   -0.44141809]
#  [ 1.31426042  1.27936924  1.30270393 ...  1.27784086  1.28855983
#   -0.38093477]
#  ...
#  [ 1.21894877  1.18789872  1.16318014 ...  1.18031612  1.1717309
#   -0.43778113]
#  [ 1.28566692  1.28302807  1.26773285 ...  1.28334038  1.27756244
#   -0.33341495]
#  [ 3.39663649  3.39069194  3.32633969 ...  3.168391    3.25489298
#   -0.23258538]]
# [[ 3.78373413e-01  3.83872790e-01  3.72365057e-01 ...  3.73537188e-01
#    3.84207873e-01 -2.82262909e-01]
#  [-8.79007087e-01 -8.79335181e-01 -8.91821437e-01 ... -9.23431901e-01
#   -9.09268364e-01 -4.48975265e-01]
#  [-1.05808300e+00 -1.05495859e+00 -1.06126894e+00 ... -1.05762008e+00
#   -1.05670669e+00  9.45930114e-01]
#  ...
#  [ 6.09388485e-04 -1.65851755e-02 -3.73734149e-02 ... -4.93755596e-02
#   -3.75786535e-02 -2.05996734e-01]
# ...

# %%
pca =PCA(n_components=2)
pct=pca.fit_transform(X_train,X_test)
principal_df=pd.DataFrame(pct,columns=['PC1','PC2'])
final_df=pd.concat([principal_df,DS[['Turnover']]],axis=1)

# %%
print('before pca\n----------------------------------------------------')
print(DS[:5])
print('after pca\n----------------------------------------------------')
print(final_df[:5])
# Out:
# before pca
# ----------------------------------------------------
#          Date Symbol Series  Prev Close   Open    High    Low   Last   Close  \
# 0  2000-01-03  TELCO     EQ      201.60  207.4  217.25  207.4  217.0  216.75
# 1  2000-01-04  TELCO     EQ      216.75  217.0  219.00  206.0  211.9  208.20
# 2  2000-01-05  TELCO     EQ      208.20  194.0  217.80  194.0  213.1  213.25
# 3  2000-01-06  TELCO     EQ      213.25  215.0  229.90  215.0  222.0  222.10
# 4  2000-01-07  TELCO     EQ      222.10  224.0  239.90  223.1  239.9  239.90
#
#      VWAP   Volume      Turnover  Trades  Deliverable Volume  %Deliverble
# 0  214.28   676126  1.448775e+13     NaN                 NaN          NaN
# 1  209.50   679215  1.422962e+13     NaN                 NaN          NaN
# 2  210.33  1120951  2.357684e+13     NaN                 NaN          NaN
# 3  225.29  1968998  4.435932e+13     NaN                 NaN          NaN
# ...

# %%
principal_df
# Out:
#            PC1       PC2
# 0    -1.986368  0.302079
# 1    -2.973529 -0.777382
# 2     3.415488 -0.000604
# 3    -3.321052 -0.843580
# 4    -0.278448 -0.214116
# ...        ...       ...
# 4239 -2.697372  3.377548
# 4240 -1.103042  0.098204
# 4241  3.163014 -0.086183
# 4242  3.409761  0.046524
# 4243  8.625646  0.732280
#
# [4244 rows x 2 columns]

# %%
fig=plt.figure(figsize=(8,8))
ax=fig.add_subplot(1,1,1)
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_title('Two Component PCA')
targets=['Turnover']
colors=['b']

for target,color in zip(targets,colors):
    index=final_df['Turnover']==target
    ax.scatter(final_df.loc[index,'PC1'],final_df.loc[index,'PC2'],c=color,s=10)
    ax.legend(targets)
    #ax.grid()
plt.plot(X,y)

pca.explained_variance_ratio_
# Out:
# array([0.88413022, 0.11546968])
